# %% [markdown]
# # This file is used to prepare a machine learning model for usage on Jetson

# %% [markdown]
# ## Setup
#
# Install dependencies and check PyTorch and GPU.

# %%
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 d273f28 torch 1.10.1 CPU
# Setup complete ✅

# %% [markdown]
# ```shell
# !python3 train.py --batch -1 # auto configuration of number of simultaneous batches
#                   --batch-size 2 # the size of one batch
#                   --epochs 1 # number of epochs
#                   --img 416 # the dimensions of the image
#                   --data data/Chess-Pieces-data.yaml # configuration file with paths to the dataset and other configurations
#                   --weights weights/yolov5n.pt # path to weights to train with and to choose the complexity of the model; yolov5n, yolov5s, yolov5m, yolov5l, yolov5x
# ```

# %%
# Train YOLOv5 on custom dataset for 300 epochs
# !python3 train.py --batch -1 --batch-size 2 --epochs 150 --img 416 --data ../datasets/Chess-Pieces_big/data.yaml --weights weights/yolov5n.pt
# Out:
# /Users/seebasti/Projects/ChessCamera/venv/lib/python3.8/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# train: weights=weights/yolov5n.pt, cfg=, data=data/Chess-Pieces-data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1, batch_size=2, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 d273f28 torch 1.10.1 CPU
#
# ...
